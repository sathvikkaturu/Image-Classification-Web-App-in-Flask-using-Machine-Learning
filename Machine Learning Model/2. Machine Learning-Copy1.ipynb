# %%
# !pip install scikit-image
# Out:
# Collecting scikit-image
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\users\91630\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.
#   Downloading scikit_image-0.18.3-cp39-cp39-win_amd64.whl (12.2 MB)
# Requirement already satisfied: scipy>=1.0.1 in c:\users\91630\appdata\local\programs\python\python39\lib\site-packages (from scikit-image) (1.7.1)
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2021.8.30-py3-none-any.whl (171 kB)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in c:\users\91630\appdata\local\programs\python\python39\lib\site-packages (from scikit-image) (3.4.2)
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.1.1-cp39-cp39-win_amd64.whl (4.2 MB)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\91630\appdata\local\programs\python\python39\lib\site-packages (from scikit-image) (1.21.1)
# Collecting networkx>=2.0
#   Downloading networkx-2.6.2-py3-none-any.whl (1.9 MB)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in c:\users\91630\appdata\local\programs\python\python39\lib\site-packages (from scikit-image) (8.3.1)
# Collecting imageio>=2.3.0
#   Downloading imageio-2.9.0-py3-none-any.whl (3.3 MB)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\91630\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\91630\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\91630\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\91630\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (0.10.0)
# Requirement already satisfied: six in c:\users\91630\appdata\local\programs\python\python39\lib\site-packages (from cycler>=0.10->matplotlib!=3.0.0,>=2.0.0->scikit-image) (1.16.0)
# Installing collected packages: tifffile, PyWavelets, networkx, imageio, scikit-image
# Successfully installed PyWavelets-1.1.1 imageio-2.9.0 networkx-2.6.2 scikit-image-0.18.3 tifffile-2021.8.30

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\91630\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (3.4.2)
# Requirement already satisfied: scipy>=1.0 in c:\users\91630\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (1.7.1)
# Requirement already satisfied: numpy>=1.15 in c:\users\91630\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (1.21.1)
# Requirement already satisfied: pandas>=0.23 in c:\users\91630\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\91630\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\91630\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\91630\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (8.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\91630\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\91630\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: six in c:\users\91630\appdata\local\programs\python\python39\lib\site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\91630\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.23->seaborn) (2021.1)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.11.2
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\users\91630\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import os
import re
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %% [raw]
# !conda install -c conda-forge scikit-image

# %%
import skimage
import skimage.color
import skimage.io
import skimage.feature
import skimage.transform

# %%
skimage.__version__
# Out:
# '0.18.3'

# %%
# load the data
data = pickle.load(open('data_animals_head_20.pickle','rb'))

# %%
data['description']
# Out:
# 'There are 20 classes and 2057 images are there. All the images are 80 x 80 (rgb)'

# %%
# split the data into independent and dependent
X = data['data'] # independent
y = data['target'] # dependent

# %%
print(X)
# Out:
# [[[[196 214 188]
#    [196 214 188]
#    [196 214 188]
#    ...
#    [ 81  76  80]
#    [ 81  76  80]
#    [ 69  64  68]]
#
#   [[196 214 188]
#    [196 214 188]
#    [196 215 187]
#    ...
#    [ 82  77  81]
#    [ 83  78  82]
#    [ 77  72  76]]
#
#   [[193 213 185]
#    [194 214 186]
#    [194 214 186]
#    ...
#    [ 82  77  81]
#    [ 81  76  80]
#    [ 78  73  77]]
#
#   ...
#
#   [[254 254 254]
#    [254 254 254]
#    [254 254 254]
#    ...
#    [ 70  65  69]
#    [ 65  60  64]
#    [ 62  57  63]]
#
#   [[254 254 254]
#    [254 254 254]
#    [254 254 254]
#    ...
#    [ 66  61  65]
#    [ 62  57  61]
#    [ 64  59  65]]
#
#   [[254 254 254]
#    [254 254 254]
#    [254 254 254]
#    ...
#    [ 56  51  55]
#    [ 79  74  78]
#    [ 70  63  70]]]
#
#
#  [[[  4   2   3]
#    [  7   5   6]
#    [  6   5   3]
#    ...
#    [ 42  31  25]
#    [ 46  35  29]
#    [ 45  32  26]]
#
#   [[  7   5   6]
#    [  5   4   2]
#    [  2   1   0]
#    ...
#    [ 22  11   5]
#    [ 43  32  26]
#    [ 47  36  30]]
#
#   [[  6   5   3]
#    [  3   2   0]
#    [  2   1   0]
#    ...
#    [ 33  24  17]
#    [ 48  39  32]
#    [ 54  45  38]]
#
#   ...
#
#   [[ 24  29   6]
#    [ 24  30   4]
#    [ 25  31   5]
#    ...
#    [116 116  80]
#    [115 117  80]
#    [127 129  92]]
#
#   [[ 22  27   4]
#    [ 23  28   5]
#    [ 24  29   6]
#    ...
#    [112 112  76]
#    [115 117  80]
#    [128 130  93]]
#
#   [[ 22  27   5]
#    [ 22  27   4]
#    [ 22  27   4]
#    ...
#    [106 106  70]
#    [112 114  77]
#    [126 128  91]]]
#
#
#  [[[104 109 102]
#    [104 111 103]
#    [108 115 107]
#    ...
#    [130 126 127]
#    [122 117 121]
#    [123 118 122]]
#
#   [[113 118 111]
#    [ 97 104  96]
#    [103 110 102]
#    ...
#    [111 107 108]
#    [129 124 128]
#    [150 145 149]]
#
#   [[126 133 125]
#    [112 119 111]
#    [110 117 109]
#    ...
#    [139 135 136]
#    [162 157 161]
#    [163 158 162]]
#
#   ...
#
#   [[214 214 202]
#    [206 206 194]
#    [202 200 187]
#    ...
#    [164 162 150]
#    [173 173 163]
#    [187 187 179]]
#
#   [[219 219 207]
#    [210 210 198]
#    [205 203 190]
#    ...
#    [170 168 156]
#    [174 174 164]
#    [188 188 180]]
#
#   [[214 214 202]
#    [201 201 189]
#    [198 196 183]
#    ...
#    [172 170 158]
#    [179 179 169]
#    [184 184 176]]]
#
#
#  ...
#
#
#  [[[147 154 113]
#    [145 152 111]
#    [146 153 112]
#    ...
#    [102 109  58]
#    [118 121  74]
#    [128 131  86]]
#
#   [[148 155 114]
#    [146 153 112]
#    [145 152 111]
#    ...
#    [120 128  71]
#    [138 142  91]
#    [151 155 105]]
#
#   [[147 154 112]
#    [146 153 111]
#    [144 151 109]
#    ...
#    [136 142  80]
#    [143 151  91]
#    [150 158  99]]
#
#   ...
#
#   [[137 142  88]
#    [146 150  99]
#    [145 148 101]
#    ...
#    [143 138 100]
#    [148 143 103]
#    [158 150 111]]
#
#   [[133 138  82]
#    [128 133  79]
#    [129 133  83]
#    ...
#    [158 153 115]
#    [157 152 112]
#    [154 149 109]]
#
#   [[130 135  79]
#    [128 133  79]
#    [135 139  88]
#    ...
#    [160 155 115]
#    [157 152 112]
#    [150 145 105]]]
#
#
#  [[[246 250 249]
#    [247 251 250]
#    [252 254 253]
#    ...
#    [136 118 114]
#    [143 124 118]
#    [145 126 120]]
#
#   [[244 248 247]
#    [252 255 255]
#    [243 245 244]
#    ...
#    [139 124 117]
#    [135 120 113]
#    [156 141 134]]
#
#   [[238 242 241]
#    [248 252 251]
#    [246 248 247]
#    ...
#    [128 118 109]
#    [128 118 109]
#    [141 131 122]]
#
#   ...
#
#   [[236 233 224]
#    [230 226 217]
#    [228 224 215]
#    ...
#    [159 142 126]
#    [152 135 119]
#    [150 133 117]]
#
#   [[234 231 222]
#    [233 230 221]
#    [229 225 216]
#    ...
#    [185 169 154]
#    [165 149 134]
#    [169 153 138]]
#
#   [[242 239 232]
#    [236 233 224]
#    [229 225 216]
#    ...
#    [193 177 162]
#    [185 169 154]
#    [175 159 144]]]
#
#
#  [[[ 85  78  32]
#    [ 79  72  26]
#    [ 79  72  26]
#    ...
#    [ 80  73  27]
#    [ 76  69  23]
#    [ 74  67  21]]
#
#   [[ 82  78  31]
#    [ 79  72  26]
#    [ 78  71  25]
#    ...
#    [ 78  71  25]
#    [ 75  68  24]
#    [ 71  64  20]]
#
#   [[ 81  77  30]
#    [ 80  73  27]
#    [ 77  70  24]
#    ...
#    [ 78  71  27]
#    [ 76  69  25]
#    [ 71  64  20]]
#
#   ...
#
#   [[ 85  55  17]
#    [ 92  60  22]
#    [ 90  58  20]
#    ...
#    [103 101  53]
#    [ 99  97  49]
#    [ 96  94  46]]
#
#   [[ 87  57  19]
#    [ 82  50  11]
#    [ 88  56  17]
#    ...
#    [104 100  53]
#    [101  97  50]
#    [ 98  94  47]]
#
#   [[ 82  53  13]
#    [ 83  51  12]
#    [ 92  60  21]
#    ...
#    [101  94  48]
#    [100  93  47]
#    [ 98  91  45]]]]

# %%
print(y)
# Out:
# ['bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', ' ...

# %%
# split the data into train and test
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2,stratify=y)

# %%
x_train.shape,x_test.shape,len(y_train),len(y_test)
# Out:
# ((1645, 80, 80, 3), (412, 80, 80, 3), 1645, 412)

# %% [markdown]
# ---
# ####  Feature Extraction
# - Hog
# [URL](https://www.analyticsvidhya.com/blog/2019/09/feature-engineering-images-introduction-hog-feature-descriptor/#:~:text=HOG%2C%20or%20Histogram%20of%20Oriented,vision%20tasks%20for%20object%20detection.)

# %%
# !dir
# Out:
#  Volume in drive D is Data
#  Volume Serial Number is 2AA6-3511
#
#  Directory of D:\DataScienceAnywhere\Udemy\Deploy_Machine_Learning_Image_Processing_Web_App_in_Heroku\Module-2-Machine Learning Model
#
# 09-09-2021  09:35    <DIR>          .
# 09-09-2021  09:35    <DIR>          ..
# 09-09-2021  09:33    <DIR>          .ipynb_checkpoints
# 02-07-2021  21:54           544,893 1. Data preparation.ipynb
# 09-09-2021  09:35         1,022,996 2. Machine Learning-Copy1.ipynb
# 09-09-2021  09:33         1,448,222 2. Machine Learning.ipynb
# 09-09-2021  09:34            39,373 3-make pipeline.ipynb
# 23-02-2021  23:45    <DIR>          data
# 02-02-2021  20:54        39,510,789 data_animals_head_20.pickle
# 07-02-2021  14:15            51,426 dog_test.jpg
# 12-02-2021  20:32           520,283 dsa_image_classification_sgd.pickle
# 07-02-2021  11:35           290,953 dsa_model_best.pickle
# 12-02-2021  20:33            78,232 dsa_scaler.pickle
# 07-02-2021  14:09           213,677 duck_test.jpg
# 07-02-2021  14:08            98,479 eagle.jpg
# 08-02-2021  02:08               927 labelenco.joblib
# 02-02-2021  21:41           122,337 lion.bmp
# 08-02-2021  01:46        38,838,261 model_pipeline.joblib
# 02-02-2021  14:45    <DIR>          PPT
# 09-02-2021  02:06    <DIR>          __pycache__
#               14 File(s)     82,780,848 bytes
#                6 Dir(s)  134,804,500,480 bytes free

# %%
img = skimage.io.imread('eagle.jpg')
plt.figure(figsize=(6,10))
plt.imshow(img)

# %%
# hog transoform
img_re = skimage.transform.rescale(img,1/3).reshape((302,215))
gray = skimage.color.rgb2gray(img_re)
feature_vector, hog_img = skimage.feature.hog(gray,orientations=9,
                    pixels_per_cell=(14,14),
                    cells_per_block=(2,2),
                    visualize=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8172/947908586.py in <module>
#       1 # hog transoform
# ----> 2 img_re = skimage.transform.rescale(img,1/3).reshape((302,215))
#       3 gray = skimage.color.rgb2gray(img_re)
#       4 feature_vector, hog_img = skimage.feature.hog(gray,orientations=9,
#       5                     pixels_per_cell=(14,14),
#
# ValueError: cannot reshape array of size 92480 into shape (302,215)

# %%
len(feature_vector)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8172/3490446998.py in <module>
# ----> 1 len(feature_vector)
#
# NameError: name 'feature_vector' is not defined

# %%
gray.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8172/264218988.py in <module>
# ----> 1 gray.shape
#
# NameError: name 'gray' is not defined

# %%
302*215
# Out:
# 64930

# %%
plt.figure(figsize=(12,10))
plt.subplot(1,2,1)
plt.imshow(gray,cmap='gray')
plt.subplot(1,2,2)
plt.imshow(hog_img,cmap='gray')

# %% [markdown]
# ---

# %% [markdown]
# ## Preprocessing
# - Grayscale
# - Hog (histogram oriented gradient) tranformer

# %%
from sklearn.base import BaseEstimator, TransformerMixin

# %%
from skimage.color import rgb2gray

# %%
class rgb2gray_transform(BaseEstimator,TransformerMixin):
    import skimage.color
    def __init__(self):
        pass
    
    def fit(self,X,y=None):
        return self
    
    def transform(self,X,y=None):
        return np.array([skimage.color.rgb2gray(x) for x in X])

# %%
x_train.shape
# Out:
# (1645, 80, 80, 3)

# %%
rgb2grayobj = rgb2gray_transform()
x_train_gray = rgb2grayobj.fit_transform(x_train)

# %%
x_train_gray.shape
# Out:
# (1645, 80, 80)

# %%
plt.subplot(1,2,1)
plt.imshow(x_train[12])
plt.subplot(1,2,2)
plt.imshow(x_train_gray[12],cmap='gray')

# %%
class hogtransformer(BaseEstimator,TransformerMixin):
    import skimage.feature
    def __init__(self,orientations=9,pixels_per_cell=(8, 8),cells_per_block=(3, 3),):
        self.orientations = orientations
        self.pixels_per_cell = pixels_per_cell
        self.cells_per_block = cells_per_block
        
        
    def fit(self,X,y=None):
        return self
    
    def transform(self,X,y=None):
        def local_hog(img):
            hog_features= skimage.feature.hog(img,orientations=self.orientations,
                                pixels_per_cell=self.pixels_per_cell,
                                cells_per_block=self.cells_per_block)
            
            return hog_features
        
        hfeatures = np.array([local_hog(x) for x in X])
        return hfeatures

# %%
hogt = hogtransformer()

# %%
x_train_hog = hogt.fit_transform(x_train_gray)

# %%
x_train_hog.shape
# Out:
# (1645, 5184)

# %% [markdown]
# ### Training Machine Learning Model

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import GridSearchCV
import sklearn.metrics
from sklearn.preprocessing import StandardScaler

# %%
model_sgd = SGDClassifier(loss='hinge',learning_rate='adaptive',
                          early_stopping=True,eta0=0.1,)

# %%
x_train.shape,x_test.shape
# Out:
# ((1645, 80, 80, 3), (412, 80, 80, 3))

# %%
grayify = rgb2gray_transform()
hogify = hogtransformer()
scalify = StandardScaler()

# %%
# pipeline
# step-1: convert into grayscale
x_train_gray = grayify.fit_transform(x_train)
# step-2: extract the features
x_train_hog = hogify.fit_transform(x_train_gray)
# step-3: Normalization
x_train_scale = scalify.fit_transform(x_train_hog)
# step-4: machine learning
model_sgd.fit(x_train_scale,y_train)
# Out:
# SGDClassifier(early_stopping=True, eta0=0.1, learning_rate='adaptive')

# %%
x_test_gray = grayify.fit_transform(x_test)
# step-2: extract the features
x_test_hog = hogify.fit_transform(x_test_gray)
# step-3: Normalization
x_test_scale = scalify.transform(x_test_hog)

y_pred_test = model_sgd.predict(x_test_scale)

# %%
y_pred_test
# Out:
# array(['eagle', 'duck', 'mouse', 'panda', 'human', 'eagle', 'deer',
#        'deer', 'rabbit', 'dog', 'cat', 'elephant', 'cat', 'elephant',
#        'chicken', 'pigeon', 'elephant', 'panda', 'monkey', 'cat', 'cat',
#        'tiger', 'pigeon', 'pigeon', 'chicken', 'dog', 'rabbit', 'natural',
#        'elephant', 'mouse', 'tiger', 'sheep', 'panda', 'mouse', 'rabbit',
#        'dog', 'elephant', 'eagle', 'human', 'deer', 'lion', 'pigeon',
#        'lion', 'human', 'wolf', 'wolf', 'dog', 'eagle', 'eagle', 'tiger',
#        'duck', 'natural', 'pigeon', 'mouse', 'rabbit', 'wolf', 'cow',
#        'bear', 'dog', 'dog', 'human', 'rabbit', 'human', 'human', 'cat',
#        'deer', 'cow', 'panda', 'tiger', 'dog', 'monkey', 'bear',
#        'chicken', 'bear', 'lion', 'sheep', 'tiger', 'duck', 'pigeon',
#        'pigeon', 'sheep', 'cow', 'cow', 'sheep', 'tiger', 'panda',
#        'sheep', 'rabbit', 'panda', 'eagle', 'monkey', 'pigeon', 'cow',
#        'monkey', 'cat', 'sheep', 'duck', 'panda', 'pigeon', 'cow',
#        'panda', 'dog', 'lion', 'deer', 'natural', 'eagle', 'mouse',
#        'panda', 'tiger', 'pigeon', 'panda', 'bear', 'duck', 'cat',
#        'panda', 'chicken', 'sheep', 'chicken', 'dog', 'chicken', 'tiger',
#        'bear', 'eagle', 'cat', 'deer', 'duck', 'monkey', 'natural',
#        'pigeon', 'pigeon', 'duck', 'chicken', 'sheep', 'pigeon',
#        'chicken', 'mouse', 'rabbit', 'sheep', 'sheep', 'monkey', 'cow',
#        'tiger', 'human', 'elephant', 'wolf', 'dog', 'rabbit', 'elephant',
#        'tiger', 'lion', 'cow', 'elephant', 'eagle', 'mouse', 'panda',
#        'rabbit', 'panda', 'panda', 'monkey', 'dog', 'sheep', 'cat',
#        'elephant', 'lion', 'rabbit', 'cat', 'rabbit', 'rabbit', 'tiger',
#        'lion', 'rabbit', 'monkey', 'eagle', 'cat', 'chicken', 'tiger',
#        'duck', 'deer', 'cow', 'bear', 'wolf', 'elephant', 'tiger',
#        'pigeon', 'rabbit', 'pigeon', 'eagle', 'chicken', 'eagle',
#        'elephant', 'monkey', 'lion', 'dog', 'chicken', 'dog', 'human',
#        'cat', 'tiger', 'bear', 'pigeon', 'bear', 'sheep', 'human',
#        'monkey', 'cow', 'duck', 'chicken', 'duck', 'cat', 'human', 'wolf',
#        'bear', 'human', 'cow', 'bear', 'deer', 'tiger', 'pigeon', 'wolf',
#        'wolf', 'panda', 'sheep', 'rabbit', 'duck', 'cat', 'bear',
#        'chicken', 'dog', 'wolf', 'chicken', 'dog', 'cow', 'elephant',
#        'deer', 'dog', 'rabbit', 'pigeon', 'rabbit', 'monkey', 'human',
#        'wolf', 'human', 'human', 'panda', 'dog', 'cow', 'panda',
#        'natural', 'cow', 'human', 'eagle', 'rabbit', 'cat', 'mouse',
#        'mouse', 'human', 'sheep', 'wolf', 'dog', 'deer', 'duck', 'tiger',
#        'deer', 'tiger', 'cat', 'bear', 'deer', 'dog', 'deer', 'duck',
#        'mouse', 'eagle', 'lion', 'panda', 'human', 'pigeon', 'deer',
#        'duck', 'panda', 'dog', 'eagle', 'elephant', 'cat', 'mouse',
#        'wolf', 'monkey', 'elephant', 'bear', 'panda', 'tiger', 'sheep',
#        'panda', 'rabbit', 'pigeon', 'pigeon', 'mouse', 'panda', 'cat',
#        'pigeon', 'deer', 'tiger', 'cat', 'mouse', 'pigeon', 'panda',
#        'monkey', 'cat', 'panda', 'duck', 'duck', 'chicken', 'rabbit',
#        'cow', 'mouse', 'cat', 'human', 'duck', 'dog', 'pigeon', 'duck',
#        'monkey', 'human', 'mouse', 'rabbit', 'sheep', 'pigeon',
#        'elephant', 'wolf', 'panda', 'tiger', 'wolf', 'tiger', 'pigeon',
#        'eagle', 'dog', 'dog', 'dog', 'dog', 'cat', 'panda', 'tiger',
#        'deer', 'cow', 'sheep', 'dog', 'duck', 'duck', 'cat', 'eagle',
#        'monkey', 'panda', 'cat', 'eagle', 'dog', 'pigeon', 'eagle',
#        'rabbit', 'elephant', 'human', 'chicken', 'wolf', 'cow', 'dog',
#        'wolf', 'cow', 'chicken', 'sheep', 'duck', 'sheep', 'pigeon',
#        'wolf', 'cat', 'duck', 'panda', 'deer', 'pigeon', 'lion', 'bear',
#        'duck', 'bear', 'deer', 'duck', 'pigeon', 'elephant', 'tiger',
#        'bear', 'cat', 'panda', 'deer', 'rabbit', 'panda', 'eagle', 'lion',
#        'bear', 'human', 'tiger', 'eagle', 'cow', 'rabbit', 'pigeon',
#        'dog', 'sheep', 'monkey', 'deer', 'bear', 'human', 'chicken',
#        'duck', 'rabbit', 'human', 'eagle', 'bear'], dtype='<U8')

# %% [markdown]
# ### Model Evaluation

# %%
cr = sklearn.metrics.classification_report(y_test,y_pred_test,output_dict=True)
pd.DataFrame(cr).T
# Out:
#               precision    recall  f1-score     support
# bear           0.421053  0.400000  0.410256   20.000000
# cat            0.769231  0.625000  0.689655   32.000000
# chicken        0.555556  0.500000  0.526316   20.000000
# cow            0.684211  0.619048  0.650000   21.000000
# deer           0.350000  0.333333  0.341463   21.000000
# dog            0.379310  0.423077  0.400000   26.000000
# duck           0.520000  0.619048  0.565217   21.000000
# eagle          0.454545  0.500000  0.476190   20.000000
# elephant       0.588235  0.500000  0.540541   20.000000
# human          0.782609  0.900000  0.837209   20.000000
# lion           0.454545  0.250000  0.322581   20.000000
# monkey         0.562500  0.450000  0.500000   20.000000
# mouse          0.533333  0.400000  0.457143   20.000000
# natural        0.000000  0.000000  0.000000    1.000000
# panda          0.633333  0.791667  0.703704   24.000000
# pigeon         0.516129  0.695652  0.592593   23.000000
# rabbit         0.440000  0.550000  0.488889   20.000000
# sheep          0.500000  0.500000  0.500000   20.000000
# tiger          0.708333  0.739130  0.723404   23.000000
# wolf           0.411765  0.350000  0.378378   20.000000
# accuracy       0.538835  0.538835  0.538835    0.538835
# macro avg      0.513234  0.507298  0.505177  412.000000
# weighted avg   0.545052  0.538835  0.536568  412.000000

# %%
metrics.cohen_kappa_score(y_test,y_pred_test)
# Out:
# 0.5130750665571895

# %% [markdown]
# # Pipeline Model

# %%
from sklearn.pipeline import Pipeline

# %%
model_pipeline = Pipeline([
    ('grascale',rgb2gray_transform()),
    ('hogtransform',hogtransformer(orientations=8,pixels_per_cell=(10,10),cells_per_block=(3,3))),
    ('scale',StandardScaler()),
    ('sgd',SGDClassifier(loss='hinge',learning_rate='adaptive',eta0=0.001))
])

# %%
model_pipeline.fit(x_train,y_train_val)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8172/2221935678.py in <module>
# ----> 1 model_pipeline.fit(x_train,y_train_val)
#
# NameError: name 'y_train_val' is not defined

# %%
y_pred = model_pipeline.predict(x_test)

# %%
y_pred

# %%
y_test_val = le.transform(y_test)

# %%
cr = sklearn.metrics.classification_report(y_test_val,y_pred,output_dict=True)
pd.DataFrame(cr).T
# Out:
# C:\Users\Srikanth\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score     support
# 0              0.933333  0.700000  0.800000   20.000000
# 1              0.777778  0.875000  0.823529   32.000000
# 2              0.875000  0.700000  0.777778   20.000000
# 3              0.777778  0.666667  0.717949   21.000000
# 4              0.772727  0.809524  0.790698   21.000000
# 5              0.724138  0.807692  0.763636   26.000000
# 6              0.904762  0.904762  0.904762   21.000000
# 7              0.692308  0.900000  0.782609   20.000000
# 8              0.809524  0.850000  0.829268   20.000000
# 9              1.000000  0.950000  0.974359   20.000000
# 10             0.720000  0.900000  0.800000   20.000000
# 11             0.900000  0.900000  0.900000   20.000000
# 12             0.904762  0.950000  0.926829   20.000000
# 13             0.000000  0.000000  0.000000    1.000000
# 14             1.000000  0.958333  0.978723   24.000000
# 15             0.850000  0.739130  0.790698   23.000000
# 16             0.823529  0.700000  0.756757   20.000000
# 17             0.739130  0.850000  0.790698   20.000000
# 18             0.954545  0.913043  0.933333   23.000000
# 19             0.888889  0.800000  0.842105   20.000000
# accuracy       0.834951  0.834951  0.834951    0.834951
# macro avg      0.802410  0.793708  0.794187  412.000000
# weighted avg   0.841046  0.834951  0.834076  412.000000

# %% [markdown]
# ## Grid Search
# - Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
estimator = Pipeline([
    ('grascale',rgb2gray_transform()),
    ('hogtransform',hogtransformer()),
    ('scale',StandardScaler()),
    ('sgd',SGDClassifier())
])

# %%
param_grid = [
    {
        'hogtransform__orientations' : [7,8,9,10],
        'hogtransform__pixels_per_cell' : [(7,7),(8,8),(9,9)],
        'hogtransform__cells_per_block' : [(2,2),(3,3)],
        'sgd__loss' : ['hinge','squared_hinge','perceptron'],
        'sgd__learning_rate': ['optimal'] 
    },
    {
        'hogtransform__orientations' : [7,8,9,10],
        'hogtransform__pixels_per_cell' : [(7,7),(8,8),(9,9)],
        'hogtransform__cells_per_block' : [(2,2),(3,3)],
        'sgd__loss': ["hinge",'squared_hinge','perceptron'],
        'sgd__learning_rate' : ['adaptive'],
        'sgd__eta0' : [0.001,0.01],
        
    }
]

# %%
param_grid = [
    {
        'hogtransform__orientations' : [7,8,9,10],
        'hogtransform__pixels_per_cell' : [(7,7),(8,8),(9,9)],
        'hogtransform__cells_per_block' : [(2,2),(3,3)],
        'sgd__loss' : ['hinge','squared_hinge','perceptron'],
        'sgd__learning_rate': ['optimal'] 
    },
    {
        'hogtransform__orientations' : [7,8,9,10],
        'hogtransform__pixels_per_cell' : [(7,7),(8,8),(9,9)],
        'hogtransform__cells_per_block' : [(2,2),(3,3)],
        'sgd__gamma' : [0.001,0.01,0.1,1,2],
        
    }
]

# %%
model_grid = GridSearchCV(estimator,
                          param_grid=param_grid,scoring='accuracy',
                          n_jobs=1,cv=3,verbose=2)

# %%
model_grid.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 216 candidates, totalling 648 fits
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=  13.8s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=  14.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=  14.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=  13.5s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=  14.9s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=  12.5s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=  13.6s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=  13.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=  13.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=  12.4s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=  11.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=  12.3s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=  12.5s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=  12.8s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=  12.3s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=  12.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=  12.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=  11.6s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   8.4s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   7.5s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   7.3s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   7.6s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   8.4s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8172/1956600560.py in <module>
# ----> 1 model_grid.fit(x_train,y_train)
#
# c:\users\91630\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\users\91630\appdata\local\programs\python\python39\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     839                 return results
#     840
# --> 841             self._run_search(evaluate_candidates)
#     842
#     843             # multimetric is determined here because in the case of a callable
#
# c:\users\91630\appdata\local\programs\python\python39\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1294     def _run_search(self, evaluate_candidates):
#    1295         """Search all candidates in param_grid"""
# -> 1296         evaluate_candidates(ParameterGrid(self.param_grid))
#    1297
#    1298
#
# c:\users\91630\appdata\local\programs\python\python39\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     793                               n_splits, n_candidates, n_candidates * n_splits))
#     794
# --> 795                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     796                                                        X, y,
#     797                                                        train=train, test=test,
#
# c:\users\91630\appdata\local\programs\python\python39\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1042                 self._iterating = self._original_iterator is not None
#    1043
# -> 1044             while self.dispatch_one_batch(iterator):
#    1045                 pass
#    1046
#
# c:\users\91630\appdata\local\programs\python\python39\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     857                 return False
#     858             else:
# --> 859                 self._dispatch(tasks)
#     860                 return True
#     861
#
# c:\users\91630\appdata\local\programs\python\python39\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     775         with self._lock:
#     776             job_idx = len(self._jobs)
# --> 777             job = self._backend.apply_async(batch, callback=cb)
#     778             # A job can complete so quickly than its callback is
#     779             # called before we get here, causing self._jobs to
#
# c:\users\91630\appdata\local\programs\python\python39\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# c:\users\91630\appdata\local\programs\python\python39\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# c:\users\91630\appdata\local\programs\python\python39\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# c:\users\91630\appdata\local\programs\python\python39\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# c:\users\91630\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     220     def __call__(self, *args, **kwargs):
#     221         with config_context(**self.config):
# --> 222             return self.function(*args, **kwargs)
#
# c:\users\91630\appdata\local\programs\python\python39\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     596             estimator.fit(X_train, **fit_params)
#     597         else:
# --> 598             estimator.fit(X_train, y_train, **fit_params)
#     599
#     600     except Exception as e:
#
# c:\users\91630\appdata\local\programs\python\python39\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     344             if self._final_estimator != 'passthrough':
#     345                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 346                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     347
#     348         return self
#
# c:\users\91630\appdata\local\programs\python\python39\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py in fit(self, X, y, coef_init, intercept_init, sample_weight)
#     727             Returns an instance of self.
#     728         """
# --> 729         return self._fit(X, y, alpha=self.alpha, C=1.0,
#     730                          loss=self.loss, learning_rate=self.learning_rate,
#     731                          coef_init=coef_init, intercept_init=intercept_init,
#
# c:\users\91630\appdata\local\programs\python\python39\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py in _fit(self, X, y, alpha, C, loss, learning_rate, coef_init, intercept_init, sample_weight)
#     567         self.t_ = 1.0
#     568
# --> 569         self._partial_fit(X, y, alpha, C, loss, learning_rate, self.max_iter,
#     570                           classes, sample_weight, coef_init, intercept_init)
#     571
#
# c:\users\91630\appdata\local\programs\python\python39\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py in _partial_fit(self, X, y, alpha, C, loss, learning_rate, max_iter, classes, sample_weight, coef_init, intercept_init)
#     519         # delegate to concrete training procedure
#     520         if n_classes > 2:
# --> 521             self._fit_multiclass(X, y, alpha=alpha, C=C,
#     522                                  learning_rate=learning_rate,
#     523                                  sample_weight=sample_weight,
#
# c:\users\91630\appdata\local\programs\python\python39\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py in _fit_multiclass(self, X, y, alpha, C, learning_rate, sample_weight, max_iter)
#     622         random_state = check_random_state(self.random_state)
#     623         seeds = random_state.randint(MAX_INT, size=len(self.classes_))
# --> 624         result = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#     625                           **_joblib_parallel_args(require="sharedmem"))(
#     626             delayed(fit_binary)(self, i, X, y, alpha, C, learning_rate,
#
# c:\users\91630\appdata\local\programs\python\python39\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1042                 self._iterating = self._original_iterator is not None
#    1043
# -> 1044             while self.dispatch_one_batch(iterator):
#    1045                 pass
#    1046
#
# c:\users\91630\appdata\local\programs\python\python39\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     857                 return False
#     858             else:
# --> 859                 self._dispatch(tasks)
#     860                 return True
#     861
#
# c:\users\91630\appdata\local\programs\python\python39\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     775         with self._lock:
#     776             job_idx = len(self._jobs)
# --> 777             job = self._backend.apply_async(batch, callback=cb)
#     778             # A job can complete so quickly than its callback is
#     779             # called before we get here, causing self._jobs to
#
# c:\users\91630\appdata\local\programs\python\python39\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# c:\users\91630\appdata\local\programs\python\python39\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# c:\users\91630\appdata\local\programs\python\python39\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# c:\users\91630\appdata\local\programs\python\python39\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# c:\users\91630\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     220     def __call__(self, *args, **kwargs):
#     221         with config_context(**self.config):
# --> 222             return self.function(*args, **kwargs)
#
# c:\users\91630\appdata\local\programs\python\python39\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py in fit_binary(est, i, X, y, alpha, C, learning_rate, max_iter, pos_weight, neg_weight, sample_weight, validation_mask, random_state)
#     434     tol = est.tol if est.tol is not None else -np.inf
#     435
# --> 436     coef, intercept, average_coef, average_intercept, n_iter_ = _plain_sgd(
#     437         coef, intercept, average_coef, average_intercept, est.loss_function_,
#     438         penalty_type, alpha, C, est.l1_ratio, dataset, validation_mask,
#
# KeyboardInterrupt:

# %%
model_grid.bes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8172/4183508028.py in <module>
# ----> 1 model_grid.score()
#
# TypeError: score() missing 1 required positional argument: 'X'

# %%
model_grid.best_params_
# Out:
# {'hogtransform__cells_per_block': (2, 2),
#  'hogtransform__orientations': 10,
#  'hogtransform__pixels_per_cell': (8, 8),
#  'sgd__learning_rate': 'optimal',
#  'sgd__loss': 'hinge'}

# %%
model_grid.best_score_
# Out:
# 0.7294849294669805

# %%
model_best = model_grid.best_estimator_

# %%
y_pred = model_best.predict(x_test)

# %%
cr = sklearn.metrics.classification_report(y_test,y_pred,output_dict=True)
pd.DataFrame(cr).T
# Out:
# C:\Users\Srikanth\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score     support
# bear           0.818182  0.900000  0.857143   20.000000
# cat            0.857143  0.750000  0.800000   32.000000
# chicken        0.782609  0.900000  0.837209   20.000000
# cow            0.631579  0.571429  0.600000   21.000000
# deer           0.760000  0.904762  0.826087   21.000000
# dog            0.625000  0.769231  0.689655   26.000000
# duck           0.705882  0.571429  0.631579   21.000000
# eagle          0.521739  0.600000  0.558140   20.000000
# elephant       0.875000  0.700000  0.777778   20.000000
# human          0.950000  0.950000  0.950000   20.000000
# lion           0.736842  0.700000  0.717949   20.000000
# monkey         0.782609  0.900000  0.837209   20.000000
# mouse          0.666667  0.800000  0.727273   20.000000
# natural        0.000000  0.000000  0.000000    1.000000
# panda          0.880000  0.916667  0.897959   24.000000
# pigeon         0.777778  0.608696  0.682927   23.000000
# rabbit         0.833333  0.500000  0.625000   20.000000
# sheep          0.440000  0.550000  0.488889   20.000000
# tiger          0.869565  0.869565  0.869565   23.000000
# wolf           0.833333  0.750000  0.789474   20.000000
# accuracy       0.747573  0.747573  0.747573    0.747573
# macro avg      0.717363  0.710589  0.708192  412.000000
# weighted avg   0.756166  0.747573  0.745926  412.000000

# %%
# save the model
pickle.dump(model_best,open('dsa_model_best.pickle','wb'))

# %% [markdown]
# ## Make Pipeline
#
#     {'hogtransform__cells_per_block': (2, 2),
#      'hogtransform__orientations': 10,
#      'hogtransform__pixels_per_cell': (8, 8),
#      'sgd__learning_rate': 'optimal',
#      'sgd__loss': 'hinge'}

# %%
from sklearn.pipeline import make_pipeline

# %%
pipeline1 = make_pipeline(rgb2gray_transform(),
                            hogtransformer(orientations=10,
                                           pixels_per_cell=(8,8),
                                           cells_per_block=(2,2)))

# %%
feature_vector = pipeline1.fit_transform(x_train)

# %%
# standard scaler
scalar = StandardScaler()
transformed_xtrain = scalar.fit_transform(feature_vector)

# %%
model = SGDClassifier(learning_rate='optimal',loss='hinge',alpha=0.01,early_stopping=True)

# %%
model.fit(transformed_xtrain,y_train)
# Out:
# SGDClassifier(alpha=0.01, early_stopping=True)

# %%
# evaluate
feature_vector = pipeline1.fit_transform(x_test)
transformed_x = scalar.transform(feature_vector)
y_pred_test = model.predict(transformed_x)

# %%
cr = pd.DataFrame(metrics.classification_report(y_test,y_pred_test,output_dict=True)).T
cr
# Out:
#               precision    recall  f1-score    support
# bear           0.846154  0.550000  0.666667   20.00000
# cat            0.756757  0.875000  0.811594   32.00000
# chicken        0.708333  0.850000  0.772727   20.00000
# cow            0.823529  0.666667  0.736842   21.00000
# deer           0.909091  0.952381  0.930233   21.00000
# dog            0.516129  0.615385  0.561404   26.00000
# duck           0.923077  0.571429  0.705882   21.00000
# eagle          0.705882  0.600000  0.648649   20.00000
# elephant       0.850000  0.850000  0.850000   20.00000
# human          0.900000  0.900000  0.900000   20.00000
# lion           0.550000  0.550000  0.550000   20.00000
# monkey         0.684211  0.650000  0.666667   20.00000
# mouse          0.850000  0.850000  0.850000   20.00000
# natural        0.000000  0.000000  0.000000    1.00000
# panda          0.920000  0.958333  0.938776   24.00000
# pigeon         0.720000  0.782609  0.750000   23.00000
# rabbit         0.882353  0.750000  0.810811   20.00000
# sheep          0.600000  0.750000  0.666667   20.00000
# tiger          0.846154  0.956522  0.897959   23.00000
# wolf           0.809524  0.850000  0.829268   20.00000
# accuracy       0.766990  0.766990  0.766990    0.76699
# macro avg      0.740060  0.726416  0.727207  412.00000
# weighted avg   0.774844  0.766990  0.764715  412.00000

# %%
# save models for flask app
pickle.dump(model,open('dsa_image_classification_sgd.pickle','wb'))

# %%
pickle.dump(scalar,open('dsa_scaler.pickle','wb'))

# %% [markdown]
# # Output Analysis

# %%
model_p = pickle.load(open('dsa_model_best.pickle','rb'))

# %%
model_p.get_params()
# Out:
# {'memory': None,
#  'steps': [('grascale', rgb2gray_transform()),
#   ('hogtransform',
#    hogtransformer(cells_per_block=(2, 2), orientations=8, pixels_per_cell=(10, 10))),
#   ('scale', StandardScaler()),
#   ('sgd', SGDClassifier(eta0=0.001))],
#  'verbose': False,
#  'grascale': rgb2gray_transform(),
#  'hogtransform': hogtransformer(cells_per_block=(2, 2), orientations=8, pixels_per_cell=(10, 10)),
#  'scale': StandardScaler(),
#  'sgd': SGDClassifier(eta0=0.001),
#  'hogtransform__cells_per_block': (2, 2),
#  'hogtransform__orientations': 8,
#  'hogtransform__pixels_per_cell': (10, 10),
#  'scale__copy': True,
#  'scale__with_mean': True,
#  'scale__with_std': True,
#  'sgd__alpha': 0.0001,
#  'sgd__average': False,
#  'sgd__class_weight': None,
#  'sgd__early_stopping': False,
#  'sgd__epsilon': 0.1,
#  'sgd__eta0': 0.001,
#  'sgd__fit_intercept': True,
#  'sgd__l1_ratio': 0.15,
#  'sgd__learning_rate': 'optimal',
#  'sgd__loss': 'hinge',
#  'sgd__max_iter': 1000,
#  'sgd__n_iter_no_change': 5,
#  'sgd__n_jobs': None,
#  'sgd__penalty': 'l2',
#  'sgd__power_t': 0.5,
#  'sgd__random_state': None,
#  'sgd__shuffle': True,
#  'sgd__tol': 0.001,
#  'sgd__validation_fraction': 0.1,
#  'sgd__verbose': 0,
#  'sgd__warm_start': False}

# %%
img_test= skimage.io.imread('tiger_test.jpg')
plt.imshow(img_test)

# %%
# image size is 80 x 80
img_resize = skimage.transform.resize(img_test,(80,80))
# rescale into 255
img_rescale = np.array(255*img_resize).astype(np.uint8)
plt.imshow(img_rescale)

# %%
# pass to pipeline model
img_reshape = img_rescale.reshape(-1,80,80,3)
print(img_reshape.shape)
result = model_pipeline.predict(img_reshape)
print(result)
# Out:
# (1, 80, 80, 3)
# [5]

# %%
# Descision Function
distance = model_pipeline.decision_function(img_reshape)[0]
print(distance)
# Out:
# [ 5.75370712 12.24500513  5.76864729 12.20746737  2.7388824  19.30485679
#   7.77682698  3.7492711   8.78288887 10.11721968 16.26141015 13.24395185
#  17.28262812 -0.30971381  1.72096413  0.71980935 18.29393238 15.27077942
#  13.23525647  5.75854397]

# %%
labels = list(data['labels'])
labels.sort()
print(labels)
# Out:
# ['bear', 'cat', 'chicken', 'cow', 'deer', 'dog', 'duck', 'eagle', 'elephant', 'human', 'lion', 'monkey', 'mouse', 'natural', 'panda', 'pigeon', 'rabbit', 'sheep', 'tiger', 'wolf']

# %%
plt.figure(figsize=(10,6))
plt.barh(labels,distance)
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
# confidence score
mean_distance = distance.mean()
std_distance = distance.std()
z = (distance - mean_distance)/std_distance
z
# Out:
# array([-0.62620517,  0.45996251, -0.62370528,  0.45368144, -1.13066594,
#         1.64126443, -0.28768314, -0.9616009 , -0.11934209,  0.10392713,
#         1.13201444,  0.627113  ,  1.30289151, -1.64077759, -1.30099088,
#        -1.46851084,  1.47210975,  0.96625544,  0.62565803, -0.62539584])

# %%
mean_distance
# Out:
# 9.496116738372246

# %%
std_distance
# Out:
# 5.976331358171906

# %%
from scipy import stats

# %%
dist = stats.t

# %%
dist.cdf(2.21719813,19)
# Out:
# 0.9804985267531022

# %%
dof = len(z) - 1
pvalues = [dist.cdf(zval,dof) for zval in z]
print(pvalues)
# Out:
# [0.2693157161111511, 0.6746184285442451, 0.2701187789365209, 0.6724013008095282, 0.13613339380733908, 0.94140393774905, 0.38835184849219784, 0.1741646039671521, 0.4531285822198086, 0.5408418151202851, 0.8641432492347143, 0.7309755940591313, 0.8959089406248415, 0.05864698735263532, 0.10440945435151623, 0.07916370072656952, 0.9213186651894776, 0.8269722933653654, 0.7305086321415764, 0.2695755643050099]

# %%
plt.figure(figsize=(10,6))
plt.barh(labels,pvalues)
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
import scipy

# %%
aa = scipy.special.softmax(z)

# %%
plt.figure(figsize=(10,6))
plt.barh(labels,aa)
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
import scipy

# %%
scipy.stats.zscore(distance)
# Out:
# array([-0.62620517,  0.45996251, -0.62370528,  0.45368144, -1.13066594,
#         1.64126443, -0.28768314, -0.9616009 , -0.11934209,  0.10392713,
#         1.13201444,  0.627113  ,  1.30289151, -1.64077759, -1.30099088,
#        -1.46851084,  1.47210975,  0.96625544,  0.62565803, -0.62539584])

# %%
z
# Out:
# array([-0.62620517,  0.45996251, -0.62370528,  0.45368144, -1.13066594,
#         1.64126443, -0.28768314, -0.9616009 , -0.11934209,  0.10392713,
#         1.13201444,  0.627113  ,  1.30289151, -1.64077759, -1.30099088,
#        -1.46851084,  1.47210975,  0.96625544,  0.62565803, -0.62539584])
